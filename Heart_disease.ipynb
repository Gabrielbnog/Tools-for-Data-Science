# %% [markdown]
# # Doenças cardíacas

# %% [markdown]
# **Importando as bibliotecas**

# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# Link do Kaggle: https://www.kaggle.com/ronitf/heart-disease-uci

# %% [markdown]
# This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them. In particular, the Cleveland database is the only one that has been used by ML researchers to
# this date. The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4.

# %% [markdown]
# **Importando a base de dados**

# %%
df = pd.read_csv("heart.csv")
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
to_drop = ['cp', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak',
           'slope', 'thal', 'target', 'ca']

# %%
df.drop(to_drop, inplace = True, axis=1)
df.head(5)
# Out:
#    age  sex  trestbps  chol
# 0   63    1       145   233
# 1   37    1       130   250
# 2   41    0       130   204
# 3   56    1       120   236
# 4   57    0       120   354

# %%
new_name = {"age": "Idade", "sex": "Sexo", "trestbps": "Pressão repouso",
            "chol": "Colesterol"}

# %%
df = df.rename(columns={"age": "Idade", "sex": "Sexo", "trestbps": "Pressão repouso", "chol": "Colesterol"})
df.head(5)
# Out:
#    Idade  Sexo  Pressão repouso  Colesterol
# 0     63     1              145         233
# 1     37     1              130         250
# 2     41     0              130         204
# 3     56     1              120         236
# 4     57     0              120         354

# %%
replace_values = {0: 'F', 1:'M'}

# %%
df = df.replace({"Sexo": replace_values})

# %%
df.head(5)
# Out:
#    Idade Sexo  Pressão repouso  Colesterol
# 0     63    M              145         233
# 1     37    M              130         250
# 2     41    F              130         204
# 3     56    M              120         236
# 4     57    F              120         354
